# %%
from cknots.analysis.ccd import CCD
from cknots.analysis.chromosome import Chromosome

# %%
chr23 = Chromosome()

# %%
chr23.load_from_file('data/results_test/chr_X/')

# %%
chr23
# Out:
# Chromosome X with 42 CCDs containing 37 links.

# %%
chr23.ccds
# Out:
# [CCD 1: [9986657, 10122474]: 0 links,
#  CCD 2: [11530745, 11776315]: 0 links,
#  CCD 3: [12701081, 12905054]: 0 links,
#  CCD 4: [12945245, 13490233]: 0 links,
#  CCD 5: [15380353, 15471282]: 0 links,
#  CCD 6: [15929005, 16213169]: 0 links,
#  CCD 7: [16825328, 17049413]: 0 links,
#  CCD 8: [22078884, 22139099]: 0 links,
#  CCD 9: [23779388, 24057434]: 0 links,
#  CCD 10: [24369371, 24503071]: 0 links,
#  CCD 11: [24838028, 25145672]: 0 links,
#  CCD 12: [26851293, 27187355]: 0 links,
#  CCD 13: [30569822, 30595301]: 0 links,
#  CCD 14: [31036062, 31426697]: 0 links,
#  CCD 15: [37745376, 37830681]: 0 links,
#  CCD 16: [39133264, 39244151]: 0 links,
#  CCD 17: [40543309, 41254811]: 0 links,
#  CCD 18: [46406577, 46799479]: 0 links,
#  CCD 19: [49837830, 49880317]: 0 links,
#  CCD 20: [49883045, 49923226]: 0 links,
#  CCD 21: [51419516, 51462545]: 0 links,
#  CCD 22: [53311696, 53483115]: 0 links,
#  CCD 23: [55907527, 55921599]: 0 links,
#  CCD 24: [71098745, 71132582]: 0 links,
# ...

# %%
chr23.get_ccd(26)
# Out:
# CCD 26: [79079565, 79414495]: 3 links

# %%
chr23.get_ccd(26).links[0].plot()
